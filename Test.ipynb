# %%
import pandas as pd
import numpy as np
df = pd.read_csv('nfl_data.csv')
df = pd.DataFrame(df)

# %%
df.columns
# Out:
# Index(['schedule_date', 'schedule_season', 'schedule_week', 'team_home',
#        'team_away', 'stadium', 'team_favorite_id', 'spread_favorite',
#        'over_under_line', 'weather_detail', 'weather_temperature',
#        'weather_wind_mph', 'weather_humidity', 'score_home', 'score_away',
#        'stadium_neutral', 'schedule_playoff', 'game_id'],
#       dtype='object')

# %%
df.tail()
# Out:
#       schedule_date  schedule_season schedule_week             team_home  \
# 12395    12/30/2018             2018            17      Tennessee Titans
# 12396    12/30/2018             2018            17        Houston Texans
# 12397    12/30/2018             2018            17  Tampa Bay Buccaneers
# 12398    12/30/2018             2018            17        Denver Broncos
# 12399    12/30/2018             2018            17     Minnesota Vikings
#
#                   team_away                              stadium  \
# 12395    Indianapolis Colts                       Nissan Stadium
# 12396  Jacksonville Jaguars                          NRG Stadium
# 12397       Atlanta Falcons                Raymond James Stadium
# 12398  Los Angeles Chargers  Sports Authority Field at Mile High
# 12399         Chicago Bears                    U.S. Bank Stadium
#
#       team_favorite_id  spread_favorite over_under_line weather_detail  \
# ...

# %%
df['stadium'].unique()
# Out:
# array(['Orange Bowl', 'Rice Stadium', 'Balboa Stadium', 'Lambeau Field',
#        'Atlanta-Fulton County Stadium', 'Busch Memorial Stadium',
#        'Kezar Stadium', 'Pitt Stadium', 'RFK Memorial Stadium',
#        'Tiger Stadium', 'War Memorial Stadium',
#        'Los Angeles Memorial Coliseum', 'Cleveland Municipal Stadium',
#        'Cotton Bowl', 'Franklin Field', 'Metropolitan Stadium',
#        'Mile High Stadium', 'Oakland Coliseum', 'Shea Stadium',
#        'Alumni Stadium', 'Memorial Stadium (Baltimore)',
#        'Kansas City Municipal Stadium', 'Yankee Stadium', 'Wrigley Field',
#        'Qualcomm Stadium', 'Tulane Stadium', 'Houston Astrodome',
#        'Nippert Stadium', 'Cinergy Field', 'Harvard Stadium',
#        'Three Rivers Stadium', 'Veterans Stadium', 'Foxboro Stadium',
#        'Soldier Field', 'Arrowhead Stadium', 'Candlestick Park',
#        'Texas Stadium', 'Yale Bowl', 'Ralph Wilson Stadium',
# ...

# %%
df_present = df[(df['schedule_season']>=2015) & (df['schedule_season']<=2017)]
df_present
# Out:
#       schedule_date  schedule_season schedule_week             team_home  \
# 11343     9/10/2015             2015             1  New England Patriots
# 11344     9/13/2015             2015             1        Dallas Cowboys
# 11345     9/13/2015             2015             1        St. Louis Rams
# 11346     9/13/2015             2015             1  Jacksonville Jaguars
# 11347     9/13/2015             2015             1   Washington Redskins
# 11348     9/13/2015             2015             1         New York Jets
# 11349     9/13/2015             2015             1       Oakland Raiders
# 11350     9/13/2015             2015             1    San Diego Chargers
# 11351     9/13/2015             2015             1         Buffalo Bills
# 11352     9/13/2015             2015             1  Tampa Bay Buccaneers
# 11353     9/13/2015             2015             1        Houston Texans
# 11354     9/13/2015             2015             1         Chicago Bears
# ...
